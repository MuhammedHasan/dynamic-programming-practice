# %% [markdown]
# # Cut Rod

# %%
import timeit
import matplotlib.pyplot as plt
from rod_cutting import RodCutter

# %%
prices = [1,  5, 8,  9, 10, 17, 17, 20, 24, 30]
cutter = RodCutter(prices)
__builtin__.__dict__.update(locals())

# %%
running_times = [timeit.timeit('cutter.cut_road(%d)' % i, number=100) for i in range(1,20)]
plt.plot(running_times)
plt.show()

# %%
running_times = [timeit.timeit('cutter.memorized_cut_rod(%d)' % i, number=500) for i in range(1, 250)]
plt.plot(running_times)
plt.show()

# %%
running_times = [timeit.timeit('cutter.bottom_up_cut_rod(%d)' % i, number=500) for i in range(1, 250)]
plt.plot(running_times)
plt.show()

# %%
x = 37

# %%
cutter.bottom_up_cut_rod(x)
# Out:
# 108

# %%
list(cutter.solution_of_rod(x))
# Out:
# [1, 6, 10, 10, 10]

# %%
print(cutter.bottom_up_cut_rod_solutions_table(x))
# Out:
# {0: 0, 1: 1, 2: 2, 3: 3, 4: 2, 5: 2, 6: 6, 7: 1, 8: 2, 9: 3, 10: 10, 11: 1, 12: 2, 13: 3, 14: 2, 15: 2, 16: 6, 17: 1, 18: 2, 19: 3, 20: 10, 21: 1, 22: 2, 23: 3, 24: 2, 25: 2, 26: 6, 27: 1, 28: 2, 29: 3, 30: 10, 31: 1, 32: 2, 33: 3, 34: 2, 35: 2, 36: 6, 37: 1}
